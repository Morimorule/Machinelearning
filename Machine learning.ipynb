# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import tensorflow as tf


# Load the CSV files
x_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/x_train.csv')
y_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/y_train.csv')
x_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/x_test.csv')

# Drop the columns 'm_power', 'Tosc', and 'Tmix'
x_train = x_train.drop(['m_power', 'Tosc', 'Tmix'], axis=1)
x_test = x_test.drop(['m_power', 'Tosc', 'Tmix'], axis=1)

# Normalize the data
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)


# One-hot encode the target variable
#num_classes = len(np.unique(y_train)) 
y_train_hot = tf.keras.utils.to_categorical(y_train['target'] - 1)

# Split the data into train, validation, and test sets


x_train, x_val, y_train, y_val = train_test_split(x_train_scaled, y_train_hot, test_size=0.2, random_state=42)



# Build the model
model = Sequential()
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(8, activation='softmax'))


# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

#train the model

history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_val, y_val))

import matplotlib.pyplot as plt
import numpy as np



# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Use the trained model to predict the target variable for the test data
y_pred = model.predict(x_test)

# Get the predicted classes from the predicted probabilities
y_pred_classes = np.argmax(y_pred, axis=1) + 1

# Create a DataFrame with the predicted classes
output = pd.DataFrame({'id': np.arange(len(y_pred_classes)), 'target': y_pred_classes})

# Save the DataFrame to a CSV file
output.to_csv('submission.csv', index=False)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 2s 3ms/step - loss: 0.5021 - accuracy: 0.8794 - val_loss: 0.0576 - val_accuracy: 0.9948
# Epoch 2/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0438 - accuracy: 0.9962 - val_loss: 0.0186 - val_accuracy: 0.9980
# Epoch 3/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0185 - accuracy: 0.9982 - val_loss: 0.0110 - val_accuracy: 0.9987
# Epoch 4/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0096 - accuracy: 0.9985 - val_loss: 0.0064 - val_accuracy: 0.9990
# Epoch 5/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 0.9988 - val_loss: 0.0041 - val_accuracy: 0.9990
# Epoch 6/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.0049 - val_accuracy: 0.9993
# Epoch 7/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.0033 - val_accuracy: 0.9993
# Epoch 8/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.0025 - val_accuracy: 0.9993
# Epoch 9/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0017 - val_accuracy: 0.9997
# Epoch 10/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.0021 - val_accuracy: 0.9993
# Epoch 11/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0014 - val_accuracy: 0.9997
# Epoch 12/50
# 384/384 [==============================] - 1s 2ms/step - loss: 7.2305e-04 - accuracy: 0.9999 - val_loss: 0.0022 - val_accuracy: 0.9997
# Epoch 13/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0023 - val_accuracy: 0.9993
# Epoch 14/50
# 384/384 [==============================] - 1s 2ms/step - loss: 5.4778e-04 - accuracy: 0.9999 - val_loss: 0.0011 - val_accuracy: 0.9997
# Epoch 15/50
# 384/384 [==============================] - 1s 3ms/step - loss: 3.6415e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 0.9997
# Epoch 16/50
# 384/384 [==============================] - 1s 4ms/step - loss: 2.5648e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9993
# Epoch 17/50
# 384/384 [==============================] - 1s 3ms/step - loss: 3.2559e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 0.9997
# Epoch 18/50
# 384/384 [==============================] - 1s 4ms/step - loss: 1.7222e-04 - accuracy: 1.0000 - val_loss: 8.6177e-04 - val_accuracy: 0.9997
# Epoch 19/50
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7268e-04 - accuracy: 1.0000 - val_loss: 6.9820e-04 - val_accuracy: 0.9997
# Epoch 20/50
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5306e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 0.9997
# Epoch 21/50
# 384/384 [==============================] - 1s 2ms/step - loss: 5.9967e-04 - accuracy: 0.9999 - val_loss: 0.0035 - val_accuracy: 0.9990
# Epoch 22/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 0.9993
# Epoch 23/50
# 384/384 [==============================] - 1s 2ms/step - loss: 4.6639e-04 - accuracy: 0.9999 - val_loss: 0.0015 - val_accuracy: 0.9997
# Epoch 24/50
# 384/384 [==============================] - 1s 2ms/step - loss: 9.0692e-05 - accuracy: 1.0000 - val_loss: 9.2831e-04 - val_accuracy: 0.9997
# Epoch 25/50
# 384/384 [==============================] - 1s 2ms/step - loss: 6.6978e-05 - accuracy: 1.0000 - val_loss: 7.9089e-04 - val_accuracy: 0.9997
# Epoch 26/50
# 384/384 [==============================] - 1s 2ms/step - loss: 4.4975e-05 - accuracy: 1.0000 - val_loss: 4.5393e-04 - val_accuracy: 0.9997
# Epoch 27/50
# 384/384 [==============================] - 1s 3ms/step - loss: 4.3331e-05 - accuracy: 1.0000 - val_loss: 5.4963e-04 - val_accuracy: 0.9997
# Epoch 28/50
# 384/384 [==============================] - 1s 3ms/step - loss: 3.6942e-05 - accuracy: 1.0000 - val_loss: 4.2286e-04 - val_accuracy: 0.9997
# Epoch 29/50
# 384/384 [==============================] - 1s 3ms/step - loss: 3.1301e-05 - accuracy: 1.0000 - val_loss: 9.2453e-04 - val_accuracy: 0.9997
# Epoch 30/50
# 384/384 [==============================] - 1s 3ms/step - loss: 9.3784e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9997
# Epoch 31/50
# 384/384 [==============================] - 1s 4ms/step - loss: 3.2702e-05 - accuracy: 1.0000 - val_loss: 5.4750e-04 - val_accuracy: 0.9997
# Epoch 32/50
# 384/384 [==============================] - 1s 3ms/step - loss: 2.9385e-05 - accuracy: 1.0000 - val_loss: 5.8267e-04 - val_accuracy: 0.9997
# Epoch 33/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.0029 - val_accuracy: 0.9997
# Epoch 34/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 9.9176e-04 - val_accuracy: 0.9997
# Epoch 35/50
# 384/384 [==============================] - 1s 2ms/step - loss: 2.6779e-04 - accuracy: 0.9999 - val_loss: 7.0263e-04 - val_accuracy: 0.9997
# Epoch 36/50
# 384/384 [==============================] - 1s 2ms/step - loss: 3.2644e-05 - accuracy: 1.0000 - val_loss: 5.6965e-04 - val_accuracy: 0.9997
# Epoch 37/50
# 384/384 [==============================] - 1s 2ms/step - loss: 2.8841e-05 - accuracy: 1.0000 - val_loss: 6.3346e-04 - val_accuracy: 0.9997
# Epoch 38/50
# 384/384 [==============================] - 1s 2ms/step - loss: 2.3734e-05 - accuracy: 1.0000 - val_loss: 5.7855e-04 - val_accuracy: 0.9997
# Epoch 39/50
# 384/384 [==============================] - 1s 2ms/step - loss: 1.9816e-05 - accuracy: 1.0000 - val_loss: 6.9559e-04 - val_accuracy: 0.9997
# Epoch 40/50
# 384/384 [==============================] - 1s 2ms/step - loss: 1.9322e-05 - accuracy: 1.0000 - val_loss: 5.5598e-04 - val_accuracy: 0.9997
# Epoch 41/50
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7086e-05 - accuracy: 1.0000 - val_loss: 7.0300e-04 - val_accuracy: 0.9997
# Epoch 42/50
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3095e-05 - accuracy: 1.0000 - val_loss: 4.8137e-04 - val_accuracy: 0.9997
# Epoch 43/50
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4727e-05 - accuracy: 1.0000 - val_loss: 4.5689e-04 - val_accuracy: 0.9997
# Epoch 44/50
# 384/384 [==============================] - 1s 3ms/step - loss: 1.1246e-05 - accuracy: 1.0000 - val_loss: 5.6184e-04 - val_accuracy: 0.9997
# Epoch 45/50
# 384/384 [==============================] - 1s 3ms/step - loss: 1.4085e-05 - accuracy: 1.0000 - val_loss: 5.7304e-04 - val_accuracy: 0.9997
# Epoch 46/50
# 384/384 [==============================] - 1s 4ms/step - loss: 7.9559e-06 - accuracy: 1.0000 - val_loss: 5.2852e-04 - val_accuracy: 0.9997
# Epoch 47/50
# 384/384 [==============================] - 1s 3ms/step - loss: 6.0437e-06 - accuracy: 1.0000 - val_loss: 5.9746e-04 - val_accuracy: 0.9997
# Epoch 48/50
# 384/384 [==============================] - 1s 2ms/step - loss: 6.7129e-06 - accuracy: 1.0000 - val_loss: 5.2799e-04 - val_accuracy: 0.9997
# Epoch 49/50
# 384/384 [==============================] - 1s 2ms/step - loss: 6.9786e-06 - accuracy: 1.0000 - val_loss: 3.4749e-04 - val_accuracy: 0.9997
# Epoch 50/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0058 - val_accuracy: 0.9980
# 120/120 [==============================] - 0s 2ms/step

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Load the CSV files
x_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/x_train.csv')
y_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/y_train.csv')
x_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/x_test.csv')

# Drop the columns 'm_power', 'Tosc', and 'Tmix'
x_train = x_train.drop(['m_power', 'Tosc', 'Tmix'], axis=1)
x_test = x_test.drop(['m_power', 'Tosc', 'Tmix'], axis=1)

# Normalize the data
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# Split the data into train, validation, and test sets
x_train, x_val, y_train, y_val = train_test_split(x_train_scaled, y_train['target'], test_size=0.2, random_state=42)

# Train the model
svm = SVC(kernel='linear', C=10, gamma=0.05)
svm.fit(x_train, y_train)

# Evaluate the model on the validation set
val_accuracy = svm.score(x_val, y_val)
print(f"Validation accuracy: {val_accuracy}")

# Use the trained model to predict the target variable for the test data
y_pred = svm.predict(x_test)

# Save the predicted target variable to a CSV file
np.savetxt('/content/drive/MyDrive/Colab Notebooks/y_pred.csv', y_pred, delimiter=',')
# Out:
# Validation accuracy: 1.0
